# %% [markdown]
# Демонстрация работы программы.
# На данный момент программа находит на изображениях объекты (предметы и многоугольник) и выделяет их контуром.

# %%
from main import run_demo, path_dataset_test
from pathlib import Path

# %%
run_demo(path_dataset_test)
